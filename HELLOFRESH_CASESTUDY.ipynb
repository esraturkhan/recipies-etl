# %% [markdown]
# # PYTHON PANDAS

# %% [markdown]
# ##### 1) Download the following dataset of Open Recipes.

# %%
# the data set is downloaded to the file named recipies-etl.

# %% [markdown]
# ##### 2) Write a script in Python that reads the recipes and extracts every recipe that has “Chilies” as one of the ingredients. Your code should allow for misspelling of the word for example Chiles as well as the singular form of the word.

# %%
import pandas as pd

# read the .json file named as recipes and then assing it to "df"
df = pd.read_json('recipes.json', lines=True)

# show the dataframe

df.head()
# Out:
#                                           name  \
# 0                     Easter Leftover Sandwich
# 1                 Pasta with Pesto Cream Sauce
# 2  Herb Roasted Pork Tenderloin with Preserves
# 3                     Chicken Florentine Pasta
# 4                          Perfect Iced Coffee
#
#                                          ingredients  \
# 0  12 whole Hard Boiled Eggs\n1/2 cup Mayonnaise\...
# 1  3/4 cups Fresh Basil Leaves\n1/2 cup Grated Pa...
# 2  2 whole Pork Tenderloins\n Salt And Pepper, to...
# 3  1 pound Penne\n4 whole Boneless, Skinless Chic...
# 4  1 pound Ground Coffee (good, Rich Roast)\n8 qu...
#
#                                                  url  \
# 0  http://thepioneerwoman.com/cooking/2013/04/eas...
# 1  http://thepioneerwoman.com/cooking/2011/06/pas...
# 2  http://thepioneerwoman.com/cooking/2011/09/her...
# 3  http://thepioneerwoman.com/cooking/2012/04/chi...
# 4  http://thepioneerwoman.com/cooking/2011/06/per...
#
#                                                image cookTime recipeYield  \
# 0  http://static.thepioneerwoman.com/cooking/file...       PT           8
# 1  http://static.thepioneerwoman.com/cooking/file...    PT10M           8
# 2  http://static.thepioneerwoman.com/cooking/file...    PT15M          12
# 3  http://static.thepioneerwoman.com/cooking/file...    PT20M          10
# 4  http://static.thepioneerwoman.com/cooking/file...       PT          24
#
#   datePublished prepTime                                        description
# 0    2013-04-01    PT15M  Got leftover Easter eggs?    Got leftover East...
# 1    2011-06-06     PT6M  I finally have basil in my garden. Basil I can...
# 2    2011-09-15     PT5M  This was yummy. And easy. And pretty! And it t...
# 3    2012-04-23    PT10M  I made this for a late lunch Saturday, and it ...
# 4    2011-06-13     PT8H  Iced coffee is my life. When I wake up, often ...

# %%
# Regular expression pattern 
pattern = r'\bchil(?:ies|es|is|e)\b'

# Filter the DataFrame 
recipes_with_chilies = df[df['ingredients'].str.contains(pattern, case=False, regex=True)]

# Display the filtered recipes
print(recipes_with_chilies)
# Out:
#                                              name  \
# 5                     Easy Green Chile Enchiladas
# 25    Spicy Stewed Beef with Creamy Cheddar Grits
# 105                               Frito Chili Pie
# 136                             Beef with Peppers
# 140                        Beef and Bean Burritos
# ...                                           ...
# 858                 Brazil Nut Butter Cups Recipe
# 898                              Baked Egg Recipe
# 927                       A Tasty Frittata Recipe
# 1031               Monica Bhide's Chile Pea Puffs
# 1037                           Golden Potstickers
#
#                                             ingredients  \
# 5     1 whole Onion, Diced\n2 Tablespoons Butter\n1 ...
# 25    2 Tablespoons Canola Oil\n2 Tablespoons Butter...
# 105   2 pounds Ground Chuck\n3 cloves Garlic, Minced...
# 136   1-1/2 pound Flank Steak, Sliced Very Thin Agai...
# 140   2 pounds Ground Beef\n1/2 whole Medium Onion\n...
# ...                                                 ...
# 858   1 1/2 cups Brazil nuts, loosely chopped\n1 tea...
# 898   2-3 tablespoons extra virgin olive oil\n3 big ...
# 927   Cilantro Chile Sauce\n2 large cloves garlic\n1...
# 1031  nonstick cooking spray (HS note: or a bit of o...
# 1037  1/2 cup sunflower oil\n8 green onions / scalli...
#
#                                                     url  \
# 5     http://thepioneerwoman.com/cooking/2012/05/eas...
# 25    http://thepioneerwoman.com/cooking/2012/01/spi...
# 105   http://thepioneerwoman.com/cooking/2011/09/fri...
# 136   http://thepioneerwoman.com/cooking/2011/03/bee...
# 140   http://thepioneerwoman.com/cooking/2010/07/bro...
# ...                                                 ...
# 858    http://www.101cookbooks.com/archives/001371.html
# 898   http://www.101cookbooks.com/archives/baked-egg...
# 927   http://www.101cookbooks.com/archives/a-tasty-f...
# 1031  http://www.101cookbooks.com/archives/monica-bh...
# 1037  http://www.101cookbooks.com/archives/golden-po...
#
#                                                   image cookTime  \
# 5     http://static.thepioneerwoman.com/cooking/file...    PT10M
# 25    http://static.thepioneerwoman.com/cooking/file...     PT3H
# 105   http://static.thepioneerwoman.com/cooking/file...     PT1H
# 136   http://static.thepioneerwoman.com/cooking/file...    PT15M
# 140   http://static.thepioneerwoman.com/cooking/file...    PT11M
# ...                                                 ...      ...
# 858   http://www.101cookbooks.com/mt-static/images/f...
# 898   http://www.101cookbooks.com/mt-static/images/f...
# 927   http://www.101cookbooks.com/mt-static/images/f...
# 1031  http://www.101cookbooks.com/mt-static/images/f...
# 1037  http://www.101cookbooks.com/mt-static/images/f...    PT10M
#
#                             recipeYield datePublished prepTime  \
# 5                                     4    2012-05-31     PT5M
# 25                                   12    2012-01-30    PT20M
# 105                                   8    2011-09-26     PT5M
# 136                                   8    2011-03-30    PT15M
# 140                                   6    2010-07-12     PT5M
# ...                                 ...           ...      ...
# 858                                        2006-03-18
# 898                 Makes six egg cups.    2007-05-18
# 927                      Serves 2 to 4.    2007-12-20
# 1031                    Makes 32 puffs.    2009-04-29
# 1037  Makes a big platter of dumplings.    2011-10-05    PT60M
#
#                                             description
# 5     When I was in Albuquerque with Marlboro Man an...
# 25    My oh my, was this good. Ultra spicy, seriousl...
# 105   We're submerged in football right now. There's...
# 136   I could eat beef stir fry every day of the wee...
# 140   First, an important clarification: The Pioneer...
# ...                                                 ...
# 858   A twist on the traditional peanut butter cup. ...
# 898   Baked eggs in edible cups with cherry tomatoes...
# 927   The prettiest, tastiest, frittata recipe. Made...
# 1031  Monica Bhide's Chile Pea Puff recipe - crispy-...
# 1037  Potstickers - For my flight to London,  I made...
#
# [67 rows x 9 columns]

# %%
# You can also see more structered and easy to read way
recipes_with_chilies.head()
# Out:
#                                             name  \
# 5                    Easy Green Chile Enchiladas
# 25   Spicy Stewed Beef with Creamy Cheddar Grits
# 105                              Frito Chili Pie
# 136                            Beef with Peppers
# 140                       Beef and Bean Burritos
#
#                                            ingredients  \
# 5    1 whole Onion, Diced\n2 Tablespoons Butter\n1 ...
# 25   2 Tablespoons Canola Oil\n2 Tablespoons Butter...
# 105  2 pounds Ground Chuck\n3 cloves Garlic, Minced...
# 136  1-1/2 pound Flank Steak, Sliced Very Thin Agai...
# 140  2 pounds Ground Beef\n1/2 whole Medium Onion\n...
#
#                                                    url  \
# 5    http://thepioneerwoman.com/cooking/2012/05/eas...
# 25   http://thepioneerwoman.com/cooking/2012/01/spi...
# 105  http://thepioneerwoman.com/cooking/2011/09/fri...
# 136  http://thepioneerwoman.com/cooking/2011/03/bee...
# 140  http://thepioneerwoman.com/cooking/2010/07/bro...
#
#                                                  image cookTime recipeYield  \
# 5    http://static.thepioneerwoman.com/cooking/file...    PT10M           4
# 25   http://static.thepioneerwoman.com/cooking/file...     PT3H          12
# 105  http://static.thepioneerwoman.com/cooking/file...     PT1H           8
# 136  http://static.thepioneerwoman.com/cooking/file...    PT15M           8
# 140  http://static.thepioneerwoman.com/cooking/file...    PT11M           6
#
#     datePublished prepTime                                        description
# 5      2012-05-31     PT5M  When I was in Albuquerque with Marlboro Man an...
# 25     2012-01-30    PT20M  My oh my, was this good. Ultra spicy, seriousl...
# 105    2011-09-26     PT5M  We're submerged in football right now. There's...
# 136    2011-03-30    PT15M  I could eat beef stir fry every day of the wee...
# 140    2010-07-12     PT5M  First, an important clarification: The Pioneer...

# %% [markdown]
# ##### 3) Add an extra field to each of the extracted recipes with the name difficulty. The difficulty field would have a value of "Hard" if the sum of prepTime and cookTime is greater than 1 hour, "Medium" if the total is between 30 minutes and 1 hour, "Easy" if the total is less than 30 minutes, and "Unknown" otherwise.

# %%
# Convert the time format in the data table to numeric values as minutes
for i in ['cookTime', 'prepTime']:
    # Find the hours and convert it to minutes
    hours = recipes_with_chilies[i].str.extract(r'(\d+)H').fillna(0).astype(int) * 60
    # Find minutes
    minutes = recipes_with_chilies[i].str.extract(r'(\d+)M').fillna(0).astype(int)
    # Create new columns for the prepTime and cookTime as a minutes
    recipes_with_chilies[i + '_minutes'] = hours + minutes

# Calculate the totalTime and record in a new column
recipes_with_chilies['totalTime'] = recipes_with_chilies['cookTime_minutes'] + recipes_with_chilies['prepTime_minutes']

print(recipes_with_chilies)

# The question aske me to add only difficulty column as a new column. However, before calculate the difficulty column i add 
#some extra columns above in purpose of preparation. It might be not good since I change the original table more than asked
#However, it makes more readable and easy to understand process step by step.




# Find the difficulty levels using lambda function

recipes_with_chilies['difficulty'] = recipes_with_chilies['totalTime'].apply(
    lambda i: 'Hard' if i > 60 else 
                           'Medium' if 30 < i <= 60 else 
                           'Easy' if i <= 30 else 'Unknown'
)

print(recipes_with_chilies)
# Out:
#                                              name  \
# 5                     Easy Green Chile Enchiladas
# 25    Spicy Stewed Beef with Creamy Cheddar Grits
# 105                               Frito Chili Pie
# 136                             Beef with Peppers
# 140                        Beef and Bean Burritos
# ...                                           ...
# 858                 Brazil Nut Butter Cups Recipe
# 898                              Baked Egg Recipe
# 927                       A Tasty Frittata Recipe
# 1031               Monica Bhide's Chile Pea Puffs
# 1037                           Golden Potstickers
#
#                                             ingredients  \
# 5     1 whole Onion, Diced\n2 Tablespoons Butter\n1 ...
# 25    2 Tablespoons Canola Oil\n2 Tablespoons Butter...
# 105   2 pounds Ground Chuck\n3 cloves Garlic, Minced...
# 136   1-1/2 pound Flank Steak, Sliced Very Thin Agai...
# 140   2 pounds Ground Beef\n1/2 whole Medium Onion\n...
# ...                                                 ...
# 858   1 1/2 cups Brazil nuts, loosely chopped\n1 tea...
# 898   2-3 tablespoons extra virgin olive oil\n3 big ...
# 927   Cilantro Chile Sauce\n2 large cloves garlic\n1...
# 1031  nonstick cooking spray (HS note: or a bit of o...
# 1037  1/2 cup sunflower oil\n8 green onions / scalli...
#
#                                                     url  \
# 5     http://thepioneerwoman.com/cooking/2012/05/eas...
# 25    http://thepioneerwoman.com/cooking/2012/01/spi...
# 105   http://thepioneerwoman.com/cooking/2011/09/fri...
# 136   http://thepioneerwoman.com/cooking/2011/03/bee...
# 140   http://thepioneerwoman.com/cooking/2010/07/bro...
# ...                                                 ...
# 858    http://www.101cookbooks.com/archives/001371.html
# 898   http://www.101cookbooks.com/archives/baked-egg...
# 927   http://www.101cookbooks.com/archives/a-tasty-f...
# 1031  http://www.101cookbooks.com/archives/monica-bh...
# 1037  http://www.101cookbooks.com/archives/golden-po...
#
#                                                   image cookTime  \
# 5     http://static.thepioneerwoman.com/cooking/file...    PT10M
# 25    http://static.thepioneerwoman.com/cooking/file...     PT3H
# 105   http://static.thepioneerwoman.com/cooking/file...     PT1H
# 136   http://static.thepioneerwoman.com/cooking/file...    PT15M
# 140   http://static.thepioneerwoman.com/cooking/file...    PT11M
# ...                                                 ...      ...
# 858   http://www.101cookbooks.com/mt-static/images/f...
# 898   http://www.101cookbooks.com/mt-static/images/f...
# 927   http://www.101cookbooks.com/mt-static/images/f...
# 1031  http://www.101cookbooks.com/mt-static/images/f...
# 1037  http://www.101cookbooks.com/mt-static/images/f...    PT10M
#
#                             recipeYield datePublished prepTime  \
# 5                                     4    2012-05-31     PT5M
# 25                                   12    2012-01-30    PT20M
# 105                                   8    2011-09-26     PT5M
# 136                                   8    2011-03-30    PT15M
# 140                                   6    2010-07-12     PT5M
# ...                                 ...           ...      ...
# 858                                        2006-03-18
# 898                 Makes six egg cups.    2007-05-18
# 927                      Serves 2 to 4.    2007-12-20
# 1031                    Makes 32 puffs.    2009-04-29
# 1037  Makes a big platter of dumplings.    2011-10-05    PT60M
#
#                                             description  cookTime_minutes  \
# 5     When I was in Albuquerque with Marlboro Man an...                10
# 25    My oh my, was this good. Ultra spicy, seriousl...               180
# 105   We're submerged in football right now. There's...                60
# 136   I could eat beef stir fry every day of the wee...                15
# 140   First, an important clarification: The Pioneer...                11
# ...                                                 ...               ...
# 858   A twist on the traditional peanut butter cup. ...                 0
# 898   Baked eggs in edible cups with cherry tomatoes...                 0
# 927   The prettiest, tastiest, frittata recipe. Made...                 0
# 1031  Monica Bhide's Chile Pea Puff recipe - crispy-...                 0
# 1037  Potstickers - For my flight to London,  I made...                10
#
#       prepTime_minutes  totalTime
# 5                    5         15
# 25                  20        200
# 105                  5         65
# 136                 15         30
# 140                  5         16
# ...                ...        ...
# 858                  0          0
# 898                  0          0
# 927                  0          0
# 1031                 0          0
# 1037                60         70
#
# [67 rows x 12 columns]
#                                              name  \
# 5                     Easy Green Chile Enchiladas
# 25    Spicy Stewed Beef with Creamy Cheddar Grits
# 105                               Frito Chili Pie
# 136                             Beef with Peppers
# 140                        Beef and Bean Burritos
# ...                                           ...
# 858                 Brazil Nut Butter Cups Recipe
# 898                              Baked Egg Recipe
# 927                       A Tasty Frittata Recipe
# 1031               Monica Bhide's Chile Pea Puffs
# 1037                           Golden Potstickers
#
#                                             ingredients  \
# 5     1 whole Onion, Diced\n2 Tablespoons Butter\n1 ...
# 25    2 Tablespoons Canola Oil\n2 Tablespoons Butter...
# 105   2 pounds Ground Chuck\n3 cloves Garlic, Minced...
# 136   1-1/2 pound Flank Steak, Sliced Very Thin Agai...
# 140   2 pounds Ground Beef\n1/2 whole Medium Onion\n...
# ...                                                 ...
# 858   1 1/2 cups Brazil nuts, loosely chopped\n1 tea...
# 898   2-3 tablespoons extra virgin olive oil\n3 big ...
# 927   Cilantro Chile Sauce\n2 large cloves garlic\n1...
# 1031  nonstick cooking spray (HS note: or a bit of o...
# 1037  1/2 cup sunflower oil\n8 green onions / scalli...
#
#                                                     url  \
# 5     http://thepioneerwoman.com/cooking/2012/05/eas...
# 25    http://thepioneerwoman.com/cooking/2012/01/spi...
# 105   http://thepioneerwoman.com/cooking/2011/09/fri...
# 136   http://thepioneerwoman.com/cooking/2011/03/bee...
# 140   http://thepioneerwoman.com/cooking/2010/07/bro...
# ...                                                 ...
# 858    http://www.101cookbooks.com/archives/001371.html
# 898   http://www.101cookbooks.com/archives/baked-egg...
# 927   http://www.101cookbooks.com/archives/a-tasty-f...
# 1031  http://www.101cookbooks.com/archives/monica-bh...
# 1037  http://www.101cookbooks.com/archives/golden-po...
#
#                                                   image cookTime  \
# 5     http://static.thepioneerwoman.com/cooking/file...    PT10M
# 25    http://static.thepioneerwoman.com/cooking/file...     PT3H
# 105   http://static.thepioneerwoman.com/cooking/file...     PT1H
# 136   http://static.thepioneerwoman.com/cooking/file...    PT15M
# 140   http://static.thepioneerwoman.com/cooking/file...    PT11M
# ...                                                 ...      ...
# 858   http://www.101cookbooks.com/mt-static/images/f...
# 898   http://www.101cookbooks.com/mt-static/images/f...
# 927   http://www.101cookbooks.com/mt-static/images/f...
# 1031  http://www.101cookbooks.com/mt-static/images/f...
# 1037  http://www.101cookbooks.com/mt-static/images/f...    PT10M
#
#                             recipeYield datePublished prepTime  \
# 5                                     4    2012-05-31     PT5M
# 25                                   12    2012-01-30    PT20M
# 105                                   8    2011-09-26     PT5M
# 136                                   8    2011-03-30    PT15M
# 140                                   6    2010-07-12     PT5M
# ...                                 ...           ...      ...
# 858                                        2006-03-18
# 898                 Makes six egg cups.    2007-05-18
# 927                      Serves 2 to 4.    2007-12-20
# 1031                    Makes 32 puffs.    2009-04-29
# 1037  Makes a big platter of dumplings.    2011-10-05    PT60M
#
#                                             description  cookTime_minutes  \
# 5     When I was in Albuquerque with Marlboro Man an...                10
# 25    My oh my, was this good. Ultra spicy, seriousl...               180
# 105   We're submerged in football right now. There's...                60
# 136   I could eat beef stir fry every day of the wee...                15
# 140   First, an important clarification: The Pioneer...                11
# ...                                                 ...               ...
# 858   A twist on the traditional peanut butter cup. ...                 0
# 898   Baked eggs in edible cups with cherry tomatoes...                 0
# 927   The prettiest, tastiest, frittata recipe. Made...                 0
# 1031  Monica Bhide's Chile Pea Puff recipe - crispy-...                 0
# 1037  Potstickers - For my flight to London,  I made...                10
#
#       prepTime_minutes  totalTime difficulty
# 5                    5         15       Easy
# 25                  20        200       Hard
# 105                  5         65       Hard
# 136                 15         30       Easy
# 140                  5         16       Easy
# ...                ...        ...        ...
# 858                  0          0       Easy
# 898                  0          0       Easy
# 927                  0          0       Easy
# 1031                 0          0       Easy
# 1037                60         70       Hard
#
# [67 rows x 13 columns]
# /var/folders/zb/_9l14txd0s78q4_9q40_rms40000gn/T/ipykernel_1616/560453032.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   recipes_with_chilies[i + '_minutes'] = hours + minutes
# /var/folders/zb/_9l14txd0s78q4_9q40_rms40000gn/T/ipykernel_1616/560453032.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   recipes_with_chilies[i + '_minutes'] = hours + minutes
# /var/folders/zb/_9l14txd0s78q4_9q40_rms40000gn/T/ipykernel_1616/560453032.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   recipes_with_chilies['totalTime'] = recipes_with_chilies['cookTime_minutes'] + recipes_with_chilies['prepTime_minutes']
# /var/folders/zb/_9l14txd0s78q4_9q40_rms40000gn/T/ipykernel_1616/560453032.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   recipes_with_chilies['difficulty'] = recipes_with_chilies['totalTime'].apply(

# %% [markdown]
# ##### 4) The resulting dataset should be saved as a *.csv file.

# %%
recipes_with_chilies.to_csv('recipes_with_chilies.csv', index=False)
